# %% [markdown]
# ## Table of Contents
#
# - [Overview](Overview.ipynb)
# - Installation
#     - Tools
#     - Editors
# - History
# - Organization
# - Fundamentals
#     - Builtins
#         - Types
#             - Number
#                 - Integer
#                 - Floating Point
#                 - Complex
#                 - Declaration
#                 - Operations
#                 - Usage
#             - String and Character
#                 - Declaration
#                 - Operations
#                 - Usage
#             - Boolean
#                 - Declaration
#                 - Operations
#                 - Usage
#             - Tuple
#                 - Declaration
#                 - Operations
#                 - Usage
#             - List
#                 - Declaration
#                 - Operations
#                 - Usage
#             - Set
#                 - Declaration
#                 - Operations
#                 - Usage
#         - Functions
#             - print
#             - input
#             - abs
#             - min
#             - max
#             - etc.
#     - Exercises
#         - Focus on getting input, processing and generating output
# - User Defined Functions
#     - Declaration
#     - Parameters
#         - Positional
#         - Keyword
#         - Default Value
#     - Return Value
# - Exceptions
#     - Handling
#         - Try
#         - Except
#         - Else
#         - Finally
#     - Exception Wrapping
#     - User Defined
#         - Declaration
#         - Usage
# - Standard Library
#     - Collections
#     - Statistics
#     - Random
#     - CSV
#     - String
#     - datetime
#     - calendar
#     - Queue
#     - Regular Expressions
#     - pprint
#     - math
#     - decimal
#     - fractions
#
# - Programming Paradigms
#     - Object-Oriented
#         - Class
#         - Methods
#             - Class vs Instance
#             - Override
#         - Attributes
#             - Class vs Instance
#         - Properties
#         - Inheritance
#     - Functional
#         - itertools
#         - functools
#         - operator
